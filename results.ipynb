# %%
import pandas as pd
from matplotlib import pyplot as plt

# %%
models=['Model 1', "Model 2", 'Model 3']
results=[12.18,9.95,19.22]

plt.bar(models ,results,color=['#C94845', '#4958B5', '#777777'])
plt.xlabel('Models')
plt.ylabel('MSE')
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>
